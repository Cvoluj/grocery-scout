# %%
from curl_cffi import requests

headers = {
    # 'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7,uk;q=0.6',
    'Cache-Control': 'no-cache',
    'Connection': 'keep-alive',
    'Content-Type': 'application/json',
    'Origin': 'https://fora.ua',
    'Pragma': 'no-cache',
    'Referer': 'https://fora.ua/',
}

json_data = {
    'method': 'GetPickupFilials',
    'data': {
        'merchantId': 2,
        'businessId': 4,
        'city': 'м. Київ',
        'lat': '',
        'lon': '',
        'distance': '',
    },
}

response = requests.post('https://api.catalog.ecom.fora.ua/api/2.0/exec/EcomCatalogGlobal', headers=headers, json=json_data)
response.json()
# Out:
# {'items': [{'title': 'м. Київ просп. Воскресенський, 20',
#    'city': 'м. Київ',
#    'address': 'просп. Воскресенський, 20',
#    'id': 21,
#    'pickup': True,
#    'delivery': False,
#    'businessId': 4,
#    'coordinates': 'u8vz0jpr8wjs',
#    'lat': 50.478005,
#    'lon': 30.595923,
#    'allCityNames': '  київ київ',
#    'openAt': '06:00:00',
#    'closeAt': '23:45:00'},
#   {'title': 'м. Київ вул. Йорданська, 20',
#    'city': 'м. Київ',
#    'address': 'вул. Йорданська, 20',
#    'id': 47,
#    'pickup': True,
#    'delivery': False,
#    'businessId': 4,
#    'coordinates': 'u8vxq0ynbjdt',
#    'lat': 50.498473,
#    'lon': 30.50629,
#    'allCityNames': '  київ київ',
#    'openAt': '08:00:00',
#    'closeAt': '23:00:00'},
#   {'title': 'м. Київ вул. Шолуденка, 16',
#    'city': 'м. Київ',
#    'address': 'вул. Шолуденка, 16',
#    'id': 92,
#    'pickup': True,
#    'delivery': False,
#    'businessId': 4,
#    'coordinates': 'u8vxj8fnr5ff',
#    'lat': 50.454432,
# ...

# %%
import requests

headers = {
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7,uk;q=0.6',
    'Cache-Control': 'no-cache',
    'Connection': 'keep-alive',
    'Content-Type': 'application/json',
    'Origin': 'https://fora.ua',
    'Pragma': 'no-cache',
    'Referer': 'https://fora.ua/',
}

json_data = {
    'method': 'GetSimpleCatalogItems',
    'data': {
        'merchantId': 2,
        'customFilter': 'чипси',
        'deliveryType': 1,
        'filialId': 3769,
        'From': 1,
        'To': 5,
    },
}

response = requests.post('https://api.catalog.ecom.fora.ua/api/2.0/exec/EcomCatalogGlobal', headers=headers, json=json_data)

# Note: json_data will not be serialized by requests
# exactly as it was in the original request.
#data = '{"method":"GetSimpleCatalogItems","data":{"merchantId":2,"customFilter":"чипси","deliveryType":1,"filialId":3769,"From":1,"To":5}}'.encode()
#response = requests.post('https://api.catalog.ecom.fora.ua/api/2.0/exec/EcomCatalogGlobal', headers=headers, data=data)
