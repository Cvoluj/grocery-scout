# %%
from curl_cffi import requests

# cookies = {
#     'sc': '034A9F41-1A17-4973-86F6-D6621C618BF9',
#     '_gcl_au': '1.1.892979765.1777487038',
#     '_ms': '054e70d5-9ae9-4505-b884-1aab9cebaadf',
#     '_ga': 'GA1.1.1817387357.1777487038',
#     '_fbp': 'fb.1.1777487038417.427826640582345267',
#     'cookie_chat_id': '86cc348eb017426d853c8f539087f162',
#     '_gcl_aw': 'GCL.1777487162.EAIaIQobChMIyLThlNeTlAMV87KDBx1TYxYXEAAYASAAEgKMOPD_BwE',
#     '_ms_s': '1',
#     'MgidSensorNVis': '3',
#     'MgidSensorHref': 'https://varus.ua/search?q=%D1%8F%D0%B9%D1%86%D1%8F%D1%96',
#     '_ga_PH0TT5PM0B': 'GS2.1.s1777487038$o1$g1$t1777487926$j60$l0$h1512508892',
# }

headers = {
    'accept': 'application/json',
    'accept-language': 'ru-RU,ru;q=0.9',
    'cache-control': 'no-cache',
    'content-type': 'application/json',
    'pragma': 'no-cache',
    'priority': 'u=1, i',
    'referer': 'https://varus.ua/search?q=%D1%8F%D0%B9%D1%86%D1%8F%D1%96',
    'sec-ch-ua': '"Google Chrome";v="147", "Not.A/Brand";v="8", "Chromium";v="147"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'traceparent': '00-1f3bcb087a37fb079db1a1b6630680d0-9290d0922f65068c-01',
    'tracestate': 'es=s:1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/147.0.0.0 Safari/537.36',
}

params = {
    '_source_exclude': 'phone,is_darkhub,fax,emails,work_time,format_id,format_group_id,region,name',
    '_source_include': '',
    'from': '0',
    'request': '{"_availableFilters":[],"_appliedFilters":[{"attribute":"delivery_methods","value":{"in":null},"scope":"default"},{"attribute":"city_id","value":8,"scope":"default"}],"_appliedSort":[],"_searchText":""}',
    'request_format': 'search-query',
    'response_format': 'compact',
    'size': '250',
    'sort': '',
}

response = requests.get(
    'https://varus.ua/api/catalog/vue_storefront_catalog_2/tms_shop/_search',
    params=params,
    # cookies=cookies,
    headers=headers,
)

# %%
response.json()
# Out:
# {'hits': [{'tms_id': '1083',
#    'city_id': '8',
#    'lat': '50.3953256',
#    'long': '30.6203891',
#    'status': '1',
#    'has_cafe': '1',
#    'delivery_methods': [{'key': 'PICKUP',
#      'payment_methods': ['CARD_NC', 'CARD_ONLINE', 'HOLD'],
#      'max_weight': 50000,
#      'default_price': 0,
#      'last_modified': None,
#      'default_payment_method': None,
#      'min_basket_size': 299}],
#    'is_default': False,
#    'has_drive': '0',
#    'updated_at': '2025-12-18 17:20:27',
#    'short_name': 'Варус-502',
#    'inactive_reason': None,
#    'square': '714',
#    'has_own_production': '0',
#    'has_fresh_fish': '0',
#    'has_own_meat_production': '0',
#    'has_home_basket': '0',
#    'is_enabled': '1',
#    'is_darkstore': '0',
#    'upload_to_web': '1',
#    'checkout_counter_number': '2',
#    'has_wifi': '0',
#    'has_bomb_shelter': '0',
#    'has_generator': '1',
#    'delivery_shop_id': '44',
#    'has_delivery': '0',
#    'address': 'вул. Миколи Бажана, 10А',
#    'country': 'Україна',
#    'id': 37,
#    'location': {'lat': '50.3953256', 'lon': '30.6203891'},
#    'tsk': 1775595257,
#    'sgn': 'N2q3sbOZ004pkwSA1frUdIruwptX2u5QrVhCi-MnpCY',
#    '_score': 0},
#   {'tms_id': '1142',
#    'city_id': '8',
#    'lat': '50.437806',
#    'long': '30.499864',
#    'status': '1',
#    'has_cafe': '0',
#    'delivery_methods': [{'key': 'PICKUP',
#      'payment_methods': ['CARD_NC', 'CARD_ONLINE', 'HOLD'],
#      'max_weight': 50000,
#      'default_price': 0,
#      'last_modified': None,
#      'default_payment_method': None,
#      'min_basket_size': 299}],
#    'is_default': False,
#    'has_drive': '0',
#    'updated_at': '2026-03-19 20:46:11',
#    'short_name': 'Варус-519',
#    'inactive_reason': None,
#    'square': '338,9',
#    'has_own_production': '1',
#    'has_fresh_fish': '0',
#    'has_own_meat_production': '1',
#    'has_home_basket': '1',
#    'is_enabled': '1',
#    'is_darkstore': '0',
#    'upload_to_web': '1',
#    'checkout_counter_number': '3',
#    'has_wifi': '0',
#    'has_bomb_shelter': '0',
#    'has_generator': '1',
#    'delivery_shop_id': '67',
#    'has_delivery': '0',
#    'address': 'вул. Жилянська, 59',
#    'country': 'Україна',
#    'id': 90,
#    'location': {'lat': '50.437806', 'lon': '30.499864'},
#    'tsk': 1775595257,
#    'sgn': 'MPT96agwsBVp2QBH7ez4llqVRpPAt2mKuleCHkwdthA',
#    '_score': 0},
#   {'tms_id': '1107',
#    'city_id': '8',
#    'lat': '50.522636',
#    'long': '30.498884',
#    'status': '1',
#    'has_cafe': '1',
#    'delivery_methods': [{'key': 'PICKUP',
#      'payment_methods': ['CARD_NC', 'CARD_ONLINE', 'HOLD'],
#      'max_weight': 50000,
#      'default_price': 0,
#      'last_modified': None,
#      'default_payment_method': None,
#      'min_basket_size': 299}],
#    'is_default': False,
#    'has_drive': '0',
#    'updated_at': '2026-02-02 16:12:19',
#    'short_name': 'Варус-516',
#    'inactive_reason': None,
#    'square': '810,1',
#    'has_own_production': '1',
#    'has_fresh_fish': '1',
#    'has_own_meat_production': '1',
#    'has_home_basket': '1',
#    'is_enabled': '1',
#    'is_darkstore': '0',
#    'upload_to_web': '1',
#    'checkout_counter_number': 'Табачний кіоск',
#    'has_wifi': '0',
#    'has_bomb_shelter': '0',
#    'has_generator': '1',
#    'delivery_shop_id': '139261',
#    'has_delivery': '0',
#    'address': 'пр. Оболонський, 47/42 (ТЦ Оазис)',
#    'country': 'Україна',
#    'id': 130551,
#    'location': {'lat': '50.522636', 'lon': '30.498884'},
#    'tsk': 1775595257,
#    'sgn': 'AiKrDuvc633Nv3j1HERlDMuzpIQfdHRQ6xvf-XNe2xM',
#    '_score': 0},
#   {'tms_id': '1141',
#    'city_id': '8',
#    'lat': '50.4004136',
#    'long': '30.6493495',
#    'status': '1',
#    'has_cafe': '1',
#    'delivery_methods': [{'key': 'PICKUP',
#      'payment_methods': ['CARD_NC', 'CARD_ONLINE', 'HOLD'],
#      'max_weight': 50000,
#      'default_price': 0,
#      'last_modified': None,
#      'default_payment_method': None,
#      'min_basket_size': 299}],
#    'is_default': False,
#    'has_drive': '0',
#    'updated_at': '2025-12-18 17:43:18',
#    'short_name': 'Варус-518',
#    'inactive_reason': None,
#    'square': '629,48',
#    'has_own_production': '1',
#    'has_fresh_fish': '1',
#    'has_own_meat_production': '1',
#    'has_home_basket': '1',
#    'is_enabled': '1',
#    'is_darkstore': '0',
#    'upload_to_web': '1',
#    'checkout_counter_number': '5',
#    'has_wifi': '0',
#    'has_bomb_shelter': '0',
#    'has_generator': '1',
#    'delivery_shop_id': '44',
#    'has_delivery': '0',
#    'address': 'пр. Миколи Бажана, 38',
#    'country': 'Україна',
#    'id': 130563,
#    'location': {'lat': '50.4004136', 'lon': '30.6493495'},
#    'tsk': 1775595257,
#    'sgn': 'pbh40FHD-WVfjERbYD54ebBkWCjOv0M1Vmtv4NmTHos',
#    '_score': 0},
#   {'tms_id': '1170',
#    'city_id': '8',
#    'lat': '50.40538576770308',
#    'long': '30.637834233562874',
#    'status': '1',
#    'has_cafe': '1',
#    'delivery_methods': [{'key': 'PICKUP',
#      'payment_methods': ['CARD_NC', 'CARD_ONLINE', 'HOLD'],
#      'max_weight': 50000,
#      'default_price': 0,
#      'last_modified': None,
#      'default_payment_method': None,
#      'min_basket_size': 299}],
#    'is_default': False,
#    'has_drive': '0',
#    'updated_at': '2025-12-18 17:40:51',
#    'short_name': 'Варус-533',
#    'inactive_reason': None,
#    'square': '1007',
#    'has_own_production': '1',
#    'has_fresh_fish': '1',
#    'has_own_meat_production': '1',
#    'has_home_basket': '1',
#    'is_enabled': '1',
#    'is_darkstore': '0',
#    'upload_to_web': '1',
#    'checkout_counter_number': '1',
#    'has_wifi': '0',
#    'has_bomb_shelter': '0',
#    'has_generator': '1',
#    'delivery_shop_id': '44',
#    'has_delivery': '0',
#    'address': 'вул. Драгоманова 40г',
#    'country': 'Україна',
#    'id': 130578,
#    'location': {'lat': '50.40538576770308', 'lon': '30.637834233562874'},
#    'tsk': 1775595257,
#    'sgn': 'W0meMCyW_VAoDnJ77-RHvPXqjNOCsspwa5roT2mHpiI',
#    '_score': 0},
#   {'tms_id': '1166',
#    'city_id': '8',
#    'lat': '50.50082124777243',
#    'long': '30.496651520207525',
#    'status': '1',
#    'has_cafe': '1',
#    'delivery_methods': [{'key': 'PICKUP',
#      'payment_methods': ['CARD_NC', 'CARD_ONLINE', 'HOLD'],
#      'max_weight': 50000,
#      'default_price': 0,
#      'last_modified': None,
#      'default_payment_method': None,
#      'min_basket_size': 299}],
#    'is_default': False,
#    'has_drive': '0',
#    'updated_at': '2026-02-02 16:12:29',
#    'short_name': 'Варус-530',
#    'inactive_reason': None,
#    'square': '1500',
#    'has_own_production': '0',
#    'has_fresh_fish': '0',
#    'has_own_meat_production': '0',
#    'has_home_basket': '0',
#    'is_enabled': '1',
#    'is_darkstore': '0',
#    'upload_to_web': '1',
#    'checkout_counter_number': '10',
#    'has_wifi': '0',
#    'has_bomb_shelter': '0',
#    'has_generator': '1',
#    'delivery_shop_id': '139261',
#    'has_delivery': '0',
#    'address': 'вул. Героїв полку Азов, 12',
#    'country': 'Україна',
#    'id': 130700,
#    'location': {'lat': '50.50082124777243', 'lon': '30.496651520207525'},
#    'tsk': 1775595257,
#    'sgn': 'zuJIpdhdPScQPm7Y3qdpTbI16OyP6A1pS4ezSPzhygY',
#    '_score': 0},
#   {'tms_id': '1156',
#    'city_id': '8',
#    'lat': '50.4649372954671',
#    'long': '30.515409949459695',
#    'status': '1',
#    'has_cafe': '0',
#    'delivery_methods': [{'key': 'PICKUP',
#      'payment_methods': ['CARD_NC', 'CARD_ONLINE', 'HOLD'],
#      'max_weight': 50000,
#      'default_price': 0,
#      'last_modified': None,
#      'default_payment_method': None,
#      'min_basket_size': 299}],
#    'is_default': False,
#    'has_drive': '0',
#    'updated_at': '2026-03-26 13:06:13',
#    'short_name': 'Варус-525',
#    'inactive_reason': None,
#    'square': '682,08',
#    'has_own_production': '1',
#    'has_fresh_fish': '1',
#    'has_own_meat_production': '1',
#    'has_home_basket': '1',
#    'is_enabled': '1',
#    'is_darkstore': '0',
#    'upload_to_web': '1',
#    'checkout_counter_number': '1',
#    'has_wifi': '0',
#    'has_bomb_shelter': '0',
#    'has_generator': '1',
#    'delivery_shop_id': '54',
#    'has_delivery': '0',
#    'address': 'вул. Костянтинівська, 2А',
#    'country': 'Україна',
#    'id': 130723,
#    'location': {'lat': '50.4649372954671', 'lon': '30.515409949459695'},
#    'tsk': 1775595257,
#    'sgn': '2jSMU_7g3BkmpdTMU6vSOJUXmUxmHcI0guGNOAD9zE4',
#    '_score': 0},
#   {'tms_id': '1161',
#    'city_id': '8',
#    'lat': '50.403995',
#    'long': '30.649950',
#    'status': '1',
#    'has_cafe': '1',
#    'delivery_methods': [{'key': 'PICKUP',
#      'payment_methods': ['CARD_NC', 'CARD_ONLINE', 'HOLD'],
#      'max_weight': 50000,
#      'default_price': 0,
#      'last_modified': None,
#      'default_payment_method': None,
#      'min_basket_size': 299}],
#    'is_default': False,
#    'has_drive': '0',
#    'updated_at': '2025-12-18 17:45:37',
#    'short_name': 'Варус-529',
#    'inactive_reason': None,
#    'square': '604,45',
#    'has_own_production': '1',
#    'has_fresh_fish': '1',
#    'has_own_meat_production': '1',
#    'has_home_basket': '1',
#    'is_enabled': '1',
#    'is_darkstore': '0',
#    'upload_to_web': '1',
#    'checkout_counter_number': 'Тютюновий кіоск',
#    'has_wifi': '0',
#    'has_bomb_shelter': '0',
#    'has_generator': '1',
#    'delivery_shop_id': '44',
#    'has_delivery': '0',
#    'address': 'вул. Ревуцького, 40/2',
#    'country': 'Україна',
#    'id': 130729,
#    'location': {'lat': '50.403995', 'lon': '30.649950'},
#    'tsk': 1775595257,
#    'sgn': 'dDYYMZWU5JcBcj89VVBnqJeiR9fIrofee3TRL5g0Ssg',
#    '_score': 0},
#   {'tms_id': '1151',
#    'city_id': '8',
#    'lat': '50.4032419',
#    'long': '30.5113668',
#    'status': '1',
#    'has_cafe': '0',
#    'delivery_methods': [{'key': 'PICKUP',
#      'payment_methods': ['CARD_NC', 'CARD_ONLINE', 'CASH_CARD', 'HOLD'],
#      'max_weight': 50000,
#      'default_price': 0,
#      'last_modified': None,
#      'default_payment_method': None,
#      'min_basket_size': 299}],
#    'is_default': False,
#    'has_drive': '0',
#    'updated_at': '2026-04-21 21:15:41',
#    'short_name': 'Варус-523',
#    'inactive_reason': None,
#    'square': '476,42',
#    'has_own_production': '1',
#    'has_fresh_fish': '0',
#    'has_own_meat_production': '1',
#    'has_home_basket': '1',
#    'is_enabled': '1',
#    'is_darkstore': '0',
#    'upload_to_web': '1',
#    'checkout_counter_number': '1',
#    'has_wifi': '0',
#    'has_bomb_shelter': '0',
#    'has_generator': '1',
#    'delivery_shop_id': '38',
#    'has_delivery': '0',
#    'is_shipping_hub': False,
#    'address': 'вул. Деміївська, 27',
#    'country': 'Україна',
#    'id': 98,
#    'location': {'lat': '50.4032419', 'lon': '30.5113668'},
#    'tsk': 1776806172,
#    'sgn': 'Nkcv2HFCcmtW_3lFIbBhNIKWCp82fcvlHmd5TR0sk9U',
#    '_score': 0},
#   {'tms_id': '1190',
#    'city_id': '8',
#    'lat': '50.420127892958384',
#    'long': '30.52671656246088',
#    'status': '1',
#    'has_cafe': '0',
#    'delivery_methods': [{'key': 'PICKUP',
#      'payment_methods': ['CARD_NC', 'CARD_ONLINE', 'CASH_CARD', 'HOLD'],
#      'max_weight': 50000,
#      'default_price': 0,
#      'last_modified': None,
#      'default_payment_method': None,
#      'min_basket_size': 299}],
#    'is_default': False,
#    'has_drive': '0',
#    'updated_at': '2026-04-21 21:15:45',
#    'short_name': 'Варус-538',
#    'inactive_reason': None,
#    'square': None,
#    'has_own_production': '0',
#    'has_fresh_fish': '0',
#    'has_own_meat_production': '0',
#    'has_home_basket': '0',
#    'is_enabled': '1',
#    'is_darkstore': '0',
#    'upload_to_web': '1',
#    'checkout_counter_number': '',
#    'has_wifi': '0',
#    'has_bomb_shelter': '0',
#    'has_generator': '1',
#    'delivery_shop_id': '67',
#    'has_delivery': '0',
#    'is_shipping_hub': False,
#    'address': 'м. Київ, вул. Тютюника, 39А',
#    'country': 'Україна',
#    'id': 139225,
#    'location': {'lat': '50.420127892958384', 'lon': '30.52671656246088'},
#    'tsk': 1776806172,
#    'sgn': 'O7mfuUFqKuCAEQ4ymuYu8hEtYfeG1t78Bxj1Cy1OW5c',
#    '_score': 0},
#   {'tms_id': '1082',
#    'city_id': '8',
#    'lat': '50.45459695',
#    'long': '30.35233945',
#    'status': '1',
#    'has_cafe': '0',
#    'delivery_methods': [{'key': 'PICKUP',
#      'payment_methods': ['CARD_NC', 'CARD_ONLINE', 'CASH_CARD', 'HOLD'],
#      'max_weight': 50000,
#      'default_price': 0,
#      'last_modified': None,
#      'default_payment_method': None,
#      'min_basket_size': 299}],
#    'is_default': False,
#    'has_drive': '0',
#    'updated_at': '2026-04-21 21:10:28',
#    'short_name': 'Варус-501',
#    'inactive_reason': None,
#    'square': '318,6',
#    'has_own_production': '1',
#    'has_fresh_fish': '0',
#    'has_own_meat_production': '1',
#    'has_home_basket': '1',
#    'is_enabled': '1',
#    'is_darkstore': '0',
#    'upload_to_web': '1',
#    'checkout_counter_number': '1',
#    'has_wifi': '0',
#    'has_bomb_shelter': '0',
#    'has_generator': '1',
#    'delivery_shop_id': '54',
#    'has_delivery': '0',
#    'is_shipping_hub': False,
#    'address': 'пр. Перемоги, 129',
#    'country': 'Україна',
#    'id': 130724,
#    'location': {'lat': '50.45459695', 'lon': '30.35233945'},
#    'tsk': 1776805869,
#    'sgn': 'VNi9YqEoa8_dRRStV6RclRs3E6xDmnQmsGoYlT4vT70',
#    '_score': 0},
#   {'tms_id': '1171',
#    'city_id': '8',
#    'lat': '50.51658303200169',
#    'long': '30.618538249425303',
#    'status': '1',
#    'has_cafe': '1',
#    'delivery_methods': [{'key': 'PICKUP',
#      'payment_methods': ['CARD_NC', 'CARD_ONLINE', 'HOLD'],
#      'max_weight': 50000,
#      'default_price': 0,
#      'last_modified': None,
#      'default_payment_method': None,
#      'min_basket_size': 299},
#     {'key': 'DELIVERY_PRIORITY',
#      'payment_methods': ['CARD_ONLINE', 'DELIVERY_CASH', 'CARD_NC', 'HOLD'],
#      'max_weight': 50000,
#      'default_price': 89,
#      'last_modified': '2025-01-19T22:37:39.329238',
#      'default_payment_method': None,
#      'min_basket_size': 499},
#     {'key': 'DELIVERY_FOR_NOW',
#      'payment_methods': ['DELIVERY_CASH', 'CARD_NC', 'CARD_ONLINE', 'HOLD'],
#      'max_weight': 9000,
#      'default_price': 109,
#      'last_modified': '2026-03-04T23:05:43.130971',
#      'default_payment_method': None,
#      'min_basket_size': 499},
#     {'key': 'DELIVERY',
#      'payment_methods': ['CARD_ONLINE', 'CARD_NC', 'HOLD'],
#      'max_weight': 50000,
#      'default_price': 69,
#      'last_modified': '2025-03-18T22:39:56.192725',
#      'default_payment_method': None,
#      'min_basket_size': 499}],
#    'is_default': False,
#    'has_drive': '0',
#    'updated_at': '2026-04-23 06:30:25',
#    'short_name': 'Варус-534',
#    'inactive_reason': None,
#    'square': '1218',
#    'has_own_production': '1',
#    'has_fresh_fish': '1',
#    'has_own_meat_production': '1',
#    'has_home_basket': '1',
#    'is_enabled': '1',
#    'is_darkstore': '0',
#    'upload_to_web': '1',
#    'checkout_counter_number': '1',
#    'has_wifi': '0',
#    'has_bomb_shelter': '0',
#    'has_generator': '1',
#    'delivery_shop_id': '0',
#    'has_delivery': '1',
#    'is_shipping_hub': False,
#    'address': 'вул. Червоної Калини 44а',
#    'country': 'Україна',
#    'id': 139256,
#    'location': {'lat': '50.51658303200169', 'lon': '30.618538249425303'},
#    'tsk': 1776925882,
#    'sgn': 'RYJlrGLV1iVWauL5MN3ejRZ1uMbeMW0cSkcJ-iXBSQg',
#    '_score': 0},
#   {'tms_id': '1094',
#    'city_id': '8',
#    'lat': '50.51088625',
#    'long': '30.4494408',
#    'status': '1',
#    'has_cafe': '1',
#    'delivery_methods': [{'key': 'PICKUP',
#      'payment_methods': ['CARD_NC', 'CARD_ONLINE', 'HOLD'],
#      'max_weight': 50000,
#      'default_price': 0,
#      'last_modified': None,
#      'default_payment_method': None,
#      'min_basket_size': 299},
#     {'key': 'DELIVERY_PRIORITY',
#      'payment_methods': ['CARD_ONLINE', 'DELIVERY_CASH', 'CARD_NC', 'HOLD'],
#      'max_weight': 50000,
#      'default_price': 89,
#      'last_modified': '2025-01-19T22:46:59.388159',
#      'default_payment_method': None,
#      'min_basket_size': 499},
#     {'key': 'DELIVERY_FOR_NOW',
#      'payment_methods': ['DELIVERY_CASH', 'CARD_NC', 'CARD_ONLINE', 'HOLD'],
#      'max_weight': 9000,
#      'default_price': 109,
#      'last_modified': '2025-10-07T23:45:58.200844',
#      'default_payment_method': None,
#      'min_basket_size': 499},
#     {'key': 'DELIVERY',
#      'payment_methods': ['CARD_ONLINE', 'CARD_NC', 'HOLD'],
#      'max_weight': 50000,
#      'default_price': 69,
#      'last_modified': '2024-04-16T22:45:11.998344',
#      'default_payment_method': None,
#      'min_basket_size': 499}],
#    'is_default': False,
#    'has_drive': '0',
#    'updated_at': '2026-04-23 06:30:34',
#    'short_name': 'Варус-513',
#    'inactive_reason': None,
#    'square': '1010',
#    'has_own_production': '1',
#    'has_fresh_fish': '1',
#    'has_own_meat_production': '1',
#    'has_home_basket': '1',
#    'is_enabled': '1',
#    'is_darkstore': '0',
#    'upload_to_web': '1',
#    'checkout_counter_number': '8',
#    'has_wifi': '0',
#    'has_bomb_shelter': '0',
#    'has_generator': '1',
#    'delivery_shop_id': '0',
#    'has_delivery': '1',
#    'is_shipping_hub': False,
#    'address': 'вул. Вишгородська, 45А/5',
#    'country': 'Україна',
#    'id': 139261,
#    'location': {'lat': '50.51088625', 'lon': '30.4494408'},
#    'tsk': 1776925882,
#    'sgn': 'UH8gOwzQ-ZvHHjgD4r99CVIstbduRqq-cGkS-9JgFDs',
#    '_score': 0},
#   {'tms_id': '1084',
#    'city_id': '8',
#    'lat': '50.3931109',
#    'long': '30.4856158',
#    'status': '1',
#    'has_cafe': '0',
#    'delivery_methods': [{'key': 'PICKUP',
#      'payment_methods': ['CARD_NC', 'CARD_ONLINE', 'HOLD'],
#      'max_weight': 50000,
#      'default_price': 0,
#      'last_modified': None,
#      'default_payment_method': None,
#      'min_basket_size': 299},
#     {'key': 'DELIVERY',
#      'payment_methods': ['CARD_ONLINE', 'CARD_NC', 'HOLD'],
#      'max_weight': 50000,
#      'default_price': 69,
#      'last_modified': '2026-03-11T22:16:27.567718',
#      'default_payment_method': None,
#      'min_basket_size': 499},
#     {'key': 'DELIVERY_FOR_NOW',
#      'payment_methods': ['DELIVERY_CASH', 'CARD_NC', 'CARD_ONLINE', 'HOLD'],
#      'max_weight': 9000,
#      'default_price': 109,
#      'last_modified': '2026-03-18T22:35:25.615491',
#      'default_payment_method': None,
#      'min_basket_size': 499}],
#    'is_default': True,
#    'has_drive': '0',
#    'updated_at': '2026-04-23 05:20:47',
#    'short_name': 'Варус-503',
#    'inactive_reason': None,
#    'square': '1730',
#    'has_own_production': '0',
#    'has_fresh_fish': '0',
#    'has_own_meat_production': '0',
#    'has_home_basket': '0',
#    'is_enabled': '1',
#    'is_darkstore': '0',
#    'upload_to_web': '1',
#    'checkout_counter_number': '4',
#    'has_wifi': '0',
#    'has_bomb_shelter': '0',
#    'has_generator': '1',
#    'delivery_shop_id': '130694',
#    'has_delivery': '1',
#    'is_shipping_hub': False,
#    'address': 'вул. Васильківська, 34',
#    'country': 'Україна',
#    'id': 38,
#    'location': {'lat': '50.3931109', 'lon': '30.4856158'},
#    'tsk': 1776921688,
#    'sgn': 'Rfecuu4gqmlP1byOgtg4tH1jmOj6nAh5FOzrt9eo6qI',
#    '_score': 0},
#   {'tms_id': '1093',
#    'city_id': '8',
#    'lat': '50.4157072',
#    'long': '30.6587487',
#    'status': '1',
#    'has_cafe': '0',
#    'delivery_methods': [{'key': 'PICKUP',
#      'payment_methods': ['CARD_NC', 'CARD_ONLINE', 'HOLD'],
#      'max_weight': 50000,
#      'default_price': 0,
#      'last_modified': None,
#      'default_payment_method': None,
#      'min_basket_size': 299},
#     {'key': 'DELIVERY_FOR_NOW',
#      'payment_methods': ['DELIVERY_CASH', 'CARD_NC', 'CARD_ONLINE', 'HOLD'],
#      'max_weight': 9000,
#      'default_price': 109,
#      'last_modified': '2025-09-16T23:04:25.988699',
#      'default_payment_method': None,
#      'min_basket_size': 499},
#     {'key': 'DELIVERY',
#      'payment_methods': ['CARD_ONLINE', 'CARD_NC', 'HOLD'],
#      'max_weight': 50000,
#      'default_price': 69,
#      'last_modified': '2025-03-18T22:45:24.159261',
#      'default_payment_method': None,
#      'min_basket_size': 499}],
#    'is_default': False,
#    'has_drive': '0',
#    'updated_at': '2026-04-23 05:20:50',
#    'short_name': 'Варус-512',
#    'inactive_reason': None,
#    'square': '779,1',
#    'has_own_production': '1',
#    'has_fresh_fish': '0',
#    'has_own_meat_production': '1',
#    'has_home_basket': '1',
#    'is_enabled': '1',
#    'is_darkstore': '0',
#    'upload_to_web': '1',
#    'checkout_counter_number': '8',
#    'has_wifi': '0',
#    'has_bomb_shelter': '0',
#    'has_generator': '1',
#    'delivery_shop_id': '0',
#    'has_delivery': '1',
#    'is_shipping_hub': False,
#    'address': 'вул. Харкiвське шосе, 160',
#    'country': 'Україна',
#    'id': 44,
#    'location': {'lat': '50.4157072', 'lon': '30.6587487'},
#    'tsk': 1776921688,
#    'sgn': '9VXm93PXkawnw8UQmJY4kOb-TcEw60Xj0wwFhh2kgfM',
#    '_score': 0},
#   {'tms_id': '1106',
#    'city_id': '8',
#    'lat': '50.4592365',
#    'long': '30.3579342',
#    'status': '1',
#    'has_cafe': '1',
#    'delivery_methods': [{'key': 'DELIVERY',
#      'payment_methods': ['CARD_ONLINE', 'CARD_NC', 'HOLD'],
#      'max_weight': 50000,
#      'default_price': 69,
#      'last_modified': '2026-03-19T22:21:45.73315',
#      'default_payment_method': None,
#      'min_basket_size': 499},
#     {'key': 'DELIVERY_FOR_NOW',
#      'payment_methods': ['DELIVERY_CASH', 'CARD_NC', 'CARD_ONLINE', 'HOLD'],
#      'max_weight': 9000,
#      'default_price': 109,
#      'last_modified': '2025-12-27T01:27:44.603283',
#      'default_payment_method': None,
#      'min_basket_size': 499},
#     {'key': 'PICKUP',
#      'payment_methods': ['CARD_NC', 'CARD_ONLINE', 'HOLD'],
#      'max_weight': 50000,
#      'default_price': 0,
#      'last_modified': None,
#      'default_payment_method': None,
#      'min_basket_size': 299}],
#    'is_default': True,
#    'has_drive': '0',
#    'updated_at': '2026-04-23 05:21:08',
#    'short_name': 'Варус-515',
#    'inactive_reason': None,
#    'square': '2075',
#    'has_own_production': '1',
#    'has_fresh_fish': '1',
#    'has_own_meat_production': '1',
#    'has_home_basket': '1',
#    'is_enabled': '1',
#    'is_darkstore': '0',
#    'upload_to_web': '1',
#    'checkout_counter_number': '2',
#    'has_wifi': '0',
#    'has_bomb_shelter': '0',
#    'has_generator': '1',
#    'delivery_shop_id': '130694',
#    'has_delivery': '1',
#    'is_shipping_hub': False,
#    'address': 'пр. Академіка Палладіна, 16/39 (ТЦ ACADEM-CITY)',
#    'country': 'Україна',
#    'id': 54,
#    'location': {'lat': '50.4592365', 'lon': '30.3579342'},
#    'tsk': 1776921688,
#    'sgn': 'hZ5Zz9q0ynkdU1PxpWjbfx-QmdR8At1jekvyJBbR4YU',
#    '_score': 0},
#   {'tms_id': '1091',
#    'city_id': '8',
#    'lat': '50.4582839',
#    'long': '30.6140384',
#    'status': '1',
#    'has_cafe': '1',
#    'delivery_methods': [{'key': 'DELIVERY_FOR_NOW',
#      'payment_methods': ['DELIVERY_CASH', 'CARD_NC', 'CARD_ONLINE', 'HOLD'],
#      'max_weight': 9000,
#      'default_price': 109,
#      'last_modified': '2025-10-07T23:41:55.397953',
#      'default_payment_method': None,
#      'min_basket_size': 499},
#     {'key': 'PICKUP',
#      'payment_methods': ['CARD_NC', 'CARD_ONLINE', 'HOLD'],
#      'max_weight': 50000,
#      'default_price': 0,
#      'last_modified': None,
#      'default_payment_method': None,
#      'min_basket_size': 299},
#     {'key': 'DELIVERY',
#      'payment_methods': ['CARD_ONLINE', 'CARD_NC', 'HOLD'],
#      'max_weight': 50000,
#      'default_price': 69,
#      'last_modified': '2025-03-18T22:32:06.309518',
#      'default_payment_method': None,
#      'min_basket_size': 499}],
#    'is_default': False,
#    'has_drive': '0',
#    'updated_at': '2026-04-23 05:20:50',
#    'short_name': 'Варус-510',
#    'inactive_reason': None,
#    'square': '1588',
#    'has_own_production': '1',
#    'has_fresh_fish': '1',
#    'has_own_meat_production': '1',
#    'has_home_basket': '1',
#    'is_enabled': '1',
#    'is_darkstore': '0',
#    'upload_to_web': '1',
#    'checkout_counter_number': '15',
#    'has_wifi': '0',
#    'has_bomb_shelter': '0',
#    'has_generator': '1',
#    'delivery_shop_id': '0',
#    'has_delivery': '1',
#    'is_shipping_hub': False,
#    'address': 'вул. А. Малишка, 3 (ТЦ Дитячий світ)',
#    'country': 'Україна',
#    'id': 139260,
#    'location': {'lat': '50.4582839', 'lon': '30.6140384'},
#    'tsk': 1776921688,
#    'sgn': 'jfpSTLqJJpM7tlcHRMrHnQDysMI1YVJdMZEABqljgso',
#    '_score': 0},
#   {'tms_id': '1119',
#    'city_id': '8',
#    'lat': '50.423566',
#    'long': '30.446333',
#    'status': '1',
#    'has_cafe': '1',
#    'delivery_methods': [{'key': 'PICKUP',
#      'payment_methods': ['CARD_NC', 'CARD_ONLINE', 'CASH_CARD', 'HOLD'],
#      'max_weight': 50000,
#      'default_price': 0,
#      'last_modified': None,
#      'default_payment_method': None,
#      'min_basket_size': 299},
#     {'key': 'DELIVERY',
#      'payment_methods': ['CARD_ONLINE', 'CARD_NC', 'HOLD'],
#      'max_weight': 50000,
#      'default_price': 69,
#      'last_modified': '2026-03-31T22:38:31.378777',
#      'default_payment_method': None,
#      'min_basket_size': 499}],
#    'is_default': False,
#    'has_drive': '0',
#    'updated_at': '2026-04-23 05:15:25',
#    'short_name': 'Варус-517',
#    'inactive_reason': None,
#    'square': '795,11',
#    'has_own_production': '1',
#    'has_fresh_fish': '0',
#    'has_own_meat_production': '1',
#    'has_home_basket': '1',
#    'is_enabled': '1',
#    'is_darkstore': '0',
#    'upload_to_web': '1',
#    'checkout_counter_number': '2',
#    'has_wifi': '0',
#    'has_bomb_shelter': '0',
#    'has_generator': '1',
#    'delivery_shop_id': '130694',
#    'has_delivery': '1',
#    'is_shipping_hub': False,
#    'address': 'вул. Волинська, 37',
#    'country': 'Україна',
#    'id': 67,
#    'location': {'lat': '50.423566', 'lon': '30.446333'},
#    'tsk': 1776921370,
#    'sgn': 'Tn_98NaazEa5XT_AMSodbJ7u59chFZVlORKpdlVE8xI',
#    '_score': 0}],
#  'total': {'value': 18, 'relation': 'eq'}}
